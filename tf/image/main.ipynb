# %%
import matplotlib.pyplot as plt
import pylab
import  cv2
import numpy as np

img = cv2.imread("tailin.jpeg", cv2.IMREAD_GRAYSCALE)

plt.figure(figsize=(1,1))

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
fil = np.array([
    [1, 0, 1],
    [0, 1, 0],
    [1, 0, 1]
])

kernel2 = np.ones((5, 5), np.float32) / 25

print(kernel2)

res = cv2.filter2D(img, -1, kernel2)

plt.imshow(res)

# plt.imsave("res.jpg",res)
# pylab.show()
# Out:
# [[0.04 0.04 0.04 0.04 0.04]
#  [0.04 0.04 0.04 0.04 0.04]
#  [0.04 0.04 0.04 0.04 0.04]
#  [0.04 0.04 0.04 0.04 0.04]
#  [0.04 0.04 0.04 0.04 0.04]]
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tf/tf/image/main.ipynb Cell 2 line 1
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f6a757079746572227d/tf/tf/image/main.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> print(kernel2)
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f6a757079746572227d/tf/tf/image/main.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> res = cv2.filter2D(img, -1, kernel2)
# ---> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f6a757079746572227d/tf/tf/image/main.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> cv2.imshow('tset', res)
#
# error: OpenCV(4.8.1) /io/opencv/modules/highgui/src/window.cpp:1272: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'

# %%
import cv2

import numpy as np

import torch

import torch.nn as nn

img = cv2.imread('tailin.jpeg',0)  #读入灰度图像

img = np.array(img,dtype='float32')

img = torch.from_numpy(img.reshape(1,1,img.shape[0],img.shape[1]))  # 将灰度图像转换为tensor

avgPool = nn.AvgPool2d(4)  #4*4的窗口，步长为4的平均池化

img = avgPool(img)

img = torch.squeeze(img)  #去掉1的维度

img = img.numpy().astype('uint8')  #转换格式，准备输出

cv2.imwrite("out.jpg", img)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
